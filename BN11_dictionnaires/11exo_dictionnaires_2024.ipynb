# %% [markdown]
# ##### Exercices sur les dictionnaires
# ## Exercice 1
# 1. Créer le dictionnaire `mon_dico` contenant {0 : "a", 1 : "b", 2 : "c"}.
# 2. Afficher la valeur associée à la clé 0.
# 3. Ajouter la clé 3 associée à la valeur "d".
# 4. Afficher toutes les clés à l’aide d’une boucle for.
# 5. Afficher toutes les valeurs à l’aide d’une boucle for.
# 6. Afficher tous les couples "clé : valeur" à l’aide d’une boucle for.

# %%
mon_dico =

# %% [markdown]
# ## Exercice 2
# En utilisant un dictionnaire en compréhension , créer le dictionnaire de la table de 5 : {0 : 0, 1 : 5, 2 : 10, 3 : 15, ..., 10 : 50}

# %% [markdown]
# ## Exercice 3
# On considère un dictionnaire `dico` dont toutes les valeurs sont des nombres.
# Écrire le code soustrayant 8 à chacune de ces valeurs.
# On passera ainsi de {"a" : 7, "b" :0} à {"a" : -1, "b" : -8}

# %%
dico =  {"a" : 7, "b" :0, "c" : 12, "d": -4 , "e": 2 , "f": 18 ,"g": 20 ,"h" : 11, "i": 8 ,"j": 26}

# %% [markdown]
# ## Exercice 4
# Compléter la fonction `dico2liste_cle` qui a pour paramètre un dictionnaire et qui renvoie une liste des clés de ce dictionnaire.

# %%
def dico2liste_cles(dico) :
    # à compléter
    return liste_cles

# %%
mon_dico = {"français":12, "math" : 13, "NSI" : 17, "EPS" : 15, "LVA" : 12, "LVB" : 10, "HGGSP":14}
dico2liste_cles(mon_dico)

# %% [markdown]
# ## Exercice 5 : dépouillement d'un vote
# À l’issue d’une élection à scrutin uninominal, on récupère un tableau contenant tous les noms inscrits sur les bulletins trouvés dans l’urne. Par exemple :
# `urne = ["Maurice", "Roger", "Maurice", "Marie", "Marie", "Jeanne", ...]`
# Nous voulons déterminer le vainqueur de l’élection, en un seul parcours de l’urne. Le plus pratique est d’utiliser un dictionnaire qui à chaque nom associera son nombre de voix.
# Notons qu’un des avantages d’un dictionnaire est qu’il n’y a pas besoin de savoir à l’avance qui sont les candidats, ni même combien il y en a.

# %%
def creer_dico_vote(urne) :
    # on crée un dictionnaire vide
    dico_vote = ...
    # on parcourt les éléments de urne
    # si l'élément existe dans dico_vote, on incrémente sa valeur de 1
    # sinon on crée la clé portant le nom de l'élément et on l'initialise à 1
    
    return dico_vote

# %% [markdown]
# Créer la documentation (docstring) de cette fonction `creer_dico_urne`

# %%
urne = ["Maurice", "Roger", "Maurice", "Marie", "Marie", "Jeanne"]
dico = creer_dico_vote(urne)
# trouver la valeur associée au maximum de voix en utilisant la fonction max
maximum_voix = ...
# créer une liste en compréhension des vainqueurs c'est-à-dire ceux qui ont le maximum de voix

# %% [markdown]
# ## Exercice 6: chiffrer d'un message
# Voici un dictionnaire qui permet de coder les 26 lettres de l'alphabet, l'espace et l'apostrophe '.

# %%
codage = {'a':111,'b':121,'c':211,'d':311,'e':151,'f':411,'g':113,
          'h':11,'i':21,'j':71,'k':19,'l':81,'m':100,'n':9,'o':1,
          'p':8,'q':1234,'r':1119,'s':4111,'t':5111,'u':555,'v':321,
          'w':0,'x':20,'y':30,'z':40,' ':951,"'":753}

# %% [markdown]
# A l'aide de ce dictionnaire, on veut coder le message suivant : 'bonjour'
# 1. Entrainez-vous sur quelques lettres.
# 2. Ecrire une fonction `chiffrer` qui, pour un mot et un dictionnaire de code donnés, va renvoyer le mot codé sous forme d'une liste d'entiers.
#
# Par exemple on devra avoir :
#
# ```Python
# >>> chiffrer('bonjour', codage)
# [121, 1, 9, 71, 1, 555, 1119]
# ```

# %%
def chiffrer(mot,dictionnaire):
    ''' 
    PARAM : 
    -------
    mot(str) : mot à renvoyer sous forme de code
    dictionnaire(dict) : dictionnaire associant une lettre à un nombre entier
    
    RETURN :
    --------
    (list) : liste d'entiers correspondants aux lettres codées avec le dictionnaire

    EXAMPLE :
    ----------
    chiffrer('bonjour', {'a':111,'b':121,'c':211,'d':311,'e':151,'f':411,'g':113, 'h':11,'i':21,'j':71,'k':19,'l':81,\
                            'm':100,'n':9,'o':1,'p':8,'q':1234,'r':1119,'s':4111,'t':5111,'u':555,'v':321,'w':0,'x':20,\
                            'y':30,'z':40,' ':951,"'":753})
    [121, 1, 9, 71, 1, 555, 1119]
    '''

    l = list(mot)   # ['b', 'o', 'n', 'j', 'o', 'u', 'r']
    
    # Coder chaque élément de la liste précédente l, et stocker 
    # le résultat dans une nouvelle liste t
    t = 
    
    # retourner la liste résultat

# %%
chiffrer('bonjour', codage)

# %%
chiffrer('hello',codage)

# %% [markdown]
# 3. Donner un exemple de mot qui ne peut pas être chiffré avec cette fonction `chiffrer` et le dictionnaire `codage`.
# 4. Ajouter un test pour **s'assurer que** le mot peut être chiffré à l'aide du dictionnaire donné.

# %% [markdown]
# On peut facilement construire un **dictionnaire inversé** permettant de **déchiffrer** un message en passant les valeurs du premier en clé de l'autre car toutes les valeurs sont différentes.
#
# On utilise la méthode de construction par compréhension vue dans le cours.

# %%
def dechiffrer(liste, dictionnaire):
    ''' 
    PARAM :
    -------
    liste(list) :une liste d'entiers correspondants au code
    dictionnaire(dict) : dictionnaire associant une lettre à un nombre entier
    
    RETURN :
    --------
    (str) : le mot déchiffré 
    
    EXAMPLE:
    >>> dechiffrer([121, 1, 9, 71, 1, 555, 1119], codage)
    'bonjour'
    '''

    # Ecrire en compréhension le dictionnaire inversé
    dictionnaire_inverse =

    
    # Déchiffrer chaque élément de la liste passée en paramètre 'liste',
    # et stocker le résultat dans une nouvelle liste t
    
    
    # Avec l'instruction join, transformer cette liste t en string
    # exemple :  "--".join(['h', 'e', 'l', 'l', 'o'])
    

    # Retourner le résultat

# %%
# Affichage test
print(dechiffrer([121, 1, 9, 71, 1, 555, 1119], codage))

# %% [markdown]
# ## Exercice 7 : la bataille au jeu de cartes
#
# Voici un extrait de Wikipédia concernant le *jeu de cartes*.
#
# _Le jeu de cartes français ou jeu de 52 cartes est un jeu de cartes organisées :_
# * _en 2 couleurs : noir et rouge_
# * _et en 4 enseignes françaises : pique, cœur, carreau, trèfle._
#
# On considère que la valeur d'une carte est donnée par le tableau suivant :
# ![11_carte_bataille.svg](attachment:11_carte_bataille.svg)
#
# 1. Créer un dictionnaire nommé `valeur_cartes` dont :
#     * les clés sont les noms des cartes : 2, 3, ... , 10, Valet, Dame, Roi, As
#     * les valeurs sont les valeurs de ces clés.
#
# Par exemple votre dictionnaire devra renvoyer :
#
# ``` python
# >>> valeur_cartes['valet']
# 11
# ```

# %%
# dictionnaire 'valeur_cartes' des 13 cartes tel que  valeur_cartes['valet'] = 11

# %% [markdown]
# 2. Créer un dictionnaire nommé `jeu_cartes` dont :
#     * les clés sont les 52 tuples (nom, enseigne) des cartes d'un jeu de 52 cartes :
#     `('2', 'pique')` , ... , `('as', 'pique')`, `('2', 'coeur')`, ... , `('as', 'coeur')` ...
#     * et les valeurs sont les valeurs de ces clés.
#
# Par exemple votre dictionnaire devra renvoyer :
#
# ``` python
# >>> jeu_cartes[('dame', 'pique')]
# 12
# ```
# Vous devez, bien sûr, utiliser le dictionnaire `valeur_cartes` précédent.

# %%
# dictionnaire 'jeu_carte' des 52 tuples où  jeu_carte[('dame','pique')] = 12

# %% [markdown]
# 3. Vérifier que votre dictionnaire est complet c'est-à-dire qu'il possède 52 cartes.

# %%
# Afficher la longueur de ce dictionnaire

# %% [markdown]
# 4. La fonction `random.sample()` permet de créer un échantillon, c'est-à-dire choisir aléatoirement des éléments sans remise d'une liste ou d'un dictionnaire.
#
# Exemple : un échantillon de taille 3 du dictionnaire `test` :

# %%
import random
test = {('2','pique'):2 , ('as','pique'):14, ('3','coeur'):3,  ('as','coeur'):14}
echantillon = random.sample(test.keys(),3)
print(echantillon)

# %%
# Choisir au hasard 2 cartes distinctes du jeu de 52 cartes

# %% [markdown]
# 5. Créer une fonction `bataille(jeu_cartes)` qui choisit au hasard 2 cartes distinctes, les affiche, compare leur valeurs et donne la carte gagante.
#
# Par exemple, on pourrait avoir :
#
# ``` python
# >>> bataille(jeu_cartes)
# ('dame', 'coeur') de valeur 12 bat ('9', 'pique') de valeur 9
# ```

# %%
# jeu de la bataille
# -------------------------
def bataille(jeu_cartes):
    '''
    le programme va choisir au hasard deux cartes distinctes du jeu,  les afficher, comparer leur valeurs 
    et désigner la gagnante
    PARAM 
    -----
    jeu_cartes(dict) :jeu_cartes est un dictionnaire  
    RETURN
    ------
    (tuple) : carte1 choisie, carte2 choisie , les valeurs et la carte la plus forte la carte la plus forte.
    
    EXAMPLE
    -------
    >>> bataille(jeu_cartes)
    ('dame', 'coeur') de valeur 12 bat ('9', 'pique') de valeur 9
    '''

# %% [markdown]
# ## Exercice 8 : gestion de stocks
# On décrit le contenu du stock d’un entrepôt à l’aide d’un dictionnaire.
# Par exemple {"pommes" : 200, "fraises" : 100} signifie que l’on stocke 200 kg de pommes et 100 de fraises.
# On souhaite "regrouper" deux entrepôts/dictionnaires en cumulant les valeurs associées à des clés identiques. Ainsi, si les deux entrepôts stockent des pommes, le dictionnaire créé aura pour valeur associée à "pomme" la somme des deux valeurs.
# Écrire en python la fonction regroupe qui prend en argument les deux dictionnaires et répond à la question.
# Par exemple l’appel :
# `regroupe({"pommes" : 200, "fraises" : 100}, {"pommes" : 100, "oranges" : 150}) `
# renverra `{"pommes" : 300, "fraises" : 100, "oranges" : 150}`.

# %%
def regroupe(dico1,dico2) :
    dico_regroupement = {}
    # à compléter

# %%
regroupe({"pommes" : 200, "fraises" : 100}, {"pommes" : 100, "oranges" : 150})

# %% [markdown]
# ## Facultatif
# **Améliorer le jeu de bataille**
# 1. Dans la fonction `bataille`, trouver l'erreur qui peut se produire s'il y a une bataille ( ou plusieurs à suivre). Modifier le programme pour y remédier. Vous pouvez utiliser la fonction `choice` de la bibliothèque `random` et la fonction `pop`.
# 2. Ajouter une liste contenant les cartes jouées sur 1 tour.
# 3. Modifier le programme `bataille` pour jouer jusqu'à épuisement des cartes.
# 4. Ajouter une fonction qui sépare le jeu initial en deux paquets : set1 et set2.
# 5. Ajouter une fonction qui ajoute les cartes jouées dans le set du gagnant.
# 6. Modifier le programme `bataille` pour pour jouer jusqu'à épuisement des cartes de l'un des joueurs.
# 7. Ajouter une version, joueur contre ordinateur.
